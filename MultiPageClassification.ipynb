# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Make dataset

# %%
path = "/content/drive/MyDrive/SplitDocsRes.zip"

# %%
! cp /content/drive/MyDrive/out_pages_txt.zip ./

# %%
! unzip out_pages_txt.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: out_pages/single/10 (5).tif[0].docx
#   inflating: out_pages/single/10 (5).tif[0].txt
#   inflating: out_pages/single/10 (500).tif[0].docx
#   inflating: out_pages/single/10 (500).tif[0].txt
#   inflating: out_pages/single/10 (6).tif[0].docx
#   inflating: out_pages/single/10 (6).tif[0].txt
#   inflating: out_pages/single/10 (60).tif[0].docx
#   inflating: out_pages/single/10 (60).tif[0].txt
#   inflating: out_pages/single/10 (61).tif[0].docx
#   inflating: out_pages/single/10 (61).tif[0].txt
#   inflating: out_pages/single/10 (62).tif[0].docx
#   inflating: out_pages/single/10 (62).tif[0].txt
#   inflating: out_pages/single/10 (67).tif[0].docx
#   inflating: out_pages/single/10 (67).tif[0].txt
#   inflating: out_pages/single/10 (68).tif[0].docx
#   inflating: out_pages/single/10 (68).tif[0].txt
#   inflating: out_pages/single/10 (69).tif[0].docx
#   inflating: out_pages/single/10 (69).tif[0].txt
#   inflating: out_pages/single/10 (7).tif[0].docx
#   inflating: out_pages/single/10 (7).tif[0].txt
#   inflating: out_pages/single/10 (70).tif[0].docx
#   inflating: out_pages/single/10 (70).tif[0].txt
#   inflating: out_pages/single/10 (71).tif[0].docx
#   inflating: out_pages/single/10 (71).tif[0].txt
#   inflating: out_pages/single/10 (72).tif[0].docx
#   inflating: out_pages/single/10 (72).tif[0].txt
#   inflating: out_pages/single/10 (73).tif[0].docx
#   inflating: out_pages/single/10 (73).tif[0].txt
#   inflating: out_pages/single/10 (74).tif[0].docx
#   inflating: out_pages/single/10 (74).tif[0].txt
#   inflating: out_pages/single/10 (75).tif[0].docx
#   inflating: out_pages/single/10 (75).tif[0].txt
#   inflating: out_pages/single/10 (77).tif[0].docx
#   inflating: out_pages/single/10 (77).tif[0].txt
#   inflating: out_pages/single/10 (78).tif[0].docx
#   inflating: out_pages/single/10 (78).tif[0].txt
#   inflating: out_pages/single/10 (79).tif[0].docx
#   inflating: out_pages/single/10 (79).tif[0].txt
#   inflating: out_pages/single/10 (8).tif[0].docx
#   inflating: out_pages/single/10 (8).tif[0].txt
#   inflating: out_pages/single/10 (80).tif[0].docx
#   inflating: out_pages/single/10 (80).tif[0].txt
#   inflating: out_pages/single/10 (81).tif[0].docx
#   inflating: out_pages/single/10 (81).tif[0].txt
#   inflating: out_pages/single/10 (82).tif[0].docx
#   inflating: out_pages/single/10 (82).tif[0].txt
#   inflating: out_pages/single/10 (83).tif[0].docx
#   inflating: out_pages/single/10 (83).tif[0].txt
#   inflating: out_pages/single/10 (84).tif[0].docx
#   inflating: out_pages/single/10 (84).tif[0].txt
#   inflating: out_pages/single/10 (85).tif[0].docx
#   inflating: out_pages/single/10 (85).tif[0].txt
#   inflating: out_pages/single/10 (86).tif[0].docx
#   inflating: out_pages/single/10 (86).tif[0].txt
#   inflating: out_pages/single/10 (87).tif[0].docx
#   inflating: out_pages/single/10 (87).tif[0].txt
#   inflating: out_pages/single/10 (88).tif[0].docx
#   inflating: out_pages/single/10 (88).tif[0].txt
#   inflating: out_pages/single/10 (89).tif[0].docx
#   inflating: out_pages/single/10 (89).tif[0].txt
#   inflating: out_pages/single/10 (9).tif[0].docx
#   inflating: out_pages/single/10 (9).tif[0].txt
#   inflating: out_pages/single/10 (90).tif[0].docx
#   inflating: out_pages/single/10 (90).tif[0].txt
#   inflating: out_pages/single/10 (91).tif[0].docx
#   inflating: out_pages/single/10 (91).tif[0].txt
#   inflating: out_pages/single/10 (92).tif[0].docx
#   inflating: out_pages/single/10 (92).tif[0].txt
#   inflating: out_pages/single/10 (93).tif[0].docx
#   inflating: out_pages/single/10 (93).tif[0].txt
#   inflating: out_pages/single/10 (94).tif[0].docx
#   inflating: out_pages/single/10 (94).tif[0].txt
#   inflating: out_pages/single/10 (95).tif[0].docx
#   inflating: out_pages/single/10 (95).tif[0].txt
#   inflating: out_pages/single/10 (96).tif[0].docx
#   inflating: out_pages/single/10 (96).tif[0].txt
#   inflating: out_pages/single/10 (97).tif[0].docx
#   inflating: out_pages/single/10 (97).tif[0].txt
#   inflating: out_pages/single/10 (98).tif[0].docx
#   inflating: out_pages/single/10 (98).tif[0].txt
#   inflating: out_pages/single/10 (99).tif[0].docx
#   inflating: out_pages/single/10 (99).tif[0].txt
#   inflating: out_pages/single/11 (1).tif[0].docx
#   inflating: out_pages/single/11 (1).tif[0].txt
#   inflating: out_pages/single/11 (10).tif[0].docx
#   inflating: out_pages/single/11 (10).tif[0].txt
#   inflating: out_pages/single/11 (100).tif[0].docx
#   inflating: out_pages/single/11 (100).tif[0].txt
#   inflating: out_pages/single/11 (101).tif[0].docx
#   inflating: out_pages/single/11 (101).tif[0].txt
#   inflating: out_pages/single/11 (102).tif[0].docx
#   inflating: out_pages/single/11 (102).tif[0].txt
#   inflating: out_pages/single/11 (103).tif[0].docx
#   inflating: out_pages/single/11 (103).tif[0].txt
#   inflating: out_pages/single/11 (104).tif[0].docx
#   inflating: out_pages/single/11 (104).tif[0].txt
#   inflating: out_pages/single/11 (105).tif[0].docx
#   inflating: out_pages/single/11 (105).tif[0].txt
#   inflating: out_pages/single/11 (106).tif[0].docx
#   inflating: out_pages/single/11 (106).tif[0].txt
#   inflating: out_pages/single/11 (107).tif[0].docx
#   inflating: out_pages/single/11 (107).tif[0].txt
#   inflating: out_pages/single/11 (108).tif[0].docx
#   inflating: out_pages/single/11 (108).tif[0].txt
#   inflating: out_pages/single/11 (109).tif[0].docx
#   inflating: out_pages/single/11 (109).tif[0].txt
#   inflating: out_pages/single/11 (11).tif[0].docx
#   inflating: out_pages/single/11 (11).tif[0].txt
#   inflating: out_pages/single/11 (110).tif[0].docx
#   inflating: out_pages/single/11 (110).tif[0].txt
#   inflating: out_pages/single/11 (111).tif[0].docx
#   inflating: out_pages/single/11 (111).tif[0].txt
#   inflating: out_pages/single/11 (112).tif[0].docx
#   inflating: out_pages/single/11 (112).tif[0].txt
#   inflating: out_pages/single/11 (113).tif[0].docx
#   inflating: out_pages/single/11 (113).tif[0].txt
#   inflating: out_pages/single/11 (114).tif[0].docx
#   inflating: out_pages/single/11 (114).tif[0].txt
#   inflating: out_pages/single/11 (115).tif[0].docx
#   inflating: out_pages/single/11 (115).tif[0].txt
#   inflating: out_pages/single/11 (116).tif[0].docx
#   inflating: out_pages/single/11 (116).tif[0].txt
#   inflating: out_pages/single/11 (117).tif[0].docx
#   inflating: out_pages/single/11 (117).tif[0].txt
#   inflating: out_pages/single/11 (118).tif[0].docx
#   inflating: out_pages/single/11 (118).tif[0].txt
#   inflating: out_pages/single/11 (119).tif[0].docx
#   inflating: out_pages/single/11 (119).tif[0].txt
#   inflating: out_pages/single/11 (12).tif[0].docx
#   inflating: out_pages/single/11 (12).tif[0].txt
#   inflating: out_pages/single/11 (120).tif[0].docx
#   inflating: out_pages/single/11 (120).tif[0].txt
#   inflating: out_pages/single/11 (121).tif[0].docx
#   inflating: out_pages/single/11 (121).tif[0].txt
#   inflating: out_pages/single/11 (122).tif[0].docx
#   inflating: out_pages/single/11 (122).tif[0].txt
#   inflating: out_pages/single/11 (123).tif[0].docx
#   inflating: out_pages/single/11 (123).tif[0].txt
#   inflating: out_pages/single/11 (124).tif[0].docx
#   inflating: out_pages/single/11 (124).tif[0].txt
#   inflating: out_pages/single/11 (125).tif[0].docx
#   inflating: out_pages/single/11 (125).tif[0].txt
#   inflating: out_pages/single/11 (126).tif[0].docx
#   inflating: out_pages/single/11 (126).tif[0].txt
#   inflating: out_pages/single/11 (127).tif[0].docx
#   inflating: out_pages/single/11 (127).tif[0].txt
#   inflating: out_pages/single/11 (128).tif[0].docx
#   inflating: out_pages/single/11 (128).tif[0].txt
#   inflating: out_pages/single/11 (129).tif[0].docx
#   inflating: out_pages/single/11 (129).tif[0].txt
#   inflating: out_pages/single/11 (13).tif[0].docx
#   inflating: out_pages/single/11 (13).tif[0].txt
#   inflating: out_pages/single/11 (131).tif[0].docx
#   inflating: out_pages/single/11 (131).tif[0].txt
#   inflating: out_pages/single/11 (132).tif[0].docx
#   inflating: out_pages/single/11 (132).tif[0].txt
#   inflating: out_pages/single/11 (133).tif[0].docx
#   inflating: out_pages/single/11 (133).tif[0].txt
#   inflating: out_pages/single/11 (134).tif[0].docx
#   inflating: out_pages/single/11 (134).tif[0].txt
#   inflating: out_pages/single/11 (135).tif[0].docx
#   inflating: out_pages/single/11 (135).tif[0].txt
#   inflating: out_pages/single/11 (136).tif[0].docx
#   inflating: out_pages/single/11 (136).tif[0].txt
#   inflating: out_pages/single/11 (137).tif[0].docx
#   inflating: out_pages/single/11 (137).tif[0].txt
#   inflating: out_pages/single/11 (138).tif[0].docx
#   inflating: out_pages/single/11 (138).tif[0].txt
#   inflating: out_pages/single/11 (139).tif[0].docx
#   inflating: out_pages/single/11 (139).tif[0].txt
#   inflating: out_pages/single/11 (14).tif[0].docx
#   inflating: out_pages/single/11 (14).tif[0].txt
#   inflating: out_pages/single/11 (140).tif[0].docx
#   inflating: out_pages/single/11 (140).tif[0].txt
#   inflating: out_pages/single/11 (141).tif[0].docx
#   inflating: out_pages/single/11 (141).tif[0].txt
#   inflating: out_pages/single/11 (142).tif[0].docx
#   inflating: out_pages/single/11 (142).tif[0].txt
#   inflating: out_pages/single/11 (143).tif[0].docx
#   inflating: out_pages/single/11 (143).tif[0].txt
#   inflating: out_pages/single/11 (144).tif[0].docx
#   inflating: out_pages/single/11 (144).tif[0].txt
#   inflating: out_pages/single/11 (145).tif[0].docx
#   inflating: out_pages/single/11 (145).tif[0].txt
#   inflating: out_pages/single/11 (146).tif[0].docx
#   inflating: out_pages/single/11 (146).tif[0].txt
#   inflating: out_pages/single/11 (147).tif[0].docx
#   inflating: out_pages/single/11 (147).tif[0].txt
#   inflating: out_pages/single/11 (148).tif[0].docx
#   inflating: out_pages/single/11 (148).tif[0].txt
#   inflating: out_pages/single/11 (149).tif[0].docx
#   inflating: out_pages/single/11 (149).tif[0].txt
#   inflating: out_pages/single/11 (15).tif[0].docx
#   inflating: out_pages/single/11 (15).tif[0].txt
#   inflating: out_pages/single/11 (150).tif[0].docx
#   inflating: out_pages/single/11 (150).tif[0].txt
#   inflating: out_pages/single/11 (151).tif[0].docx
#   inflating: out_pages/single/11 (151).tif[0].txt
#   inflating: out_pages/single/11 (152).tif[0].docx
#   inflating: out_pages/single/11 (152).tif[0].txt
#   inflating: out_pages/single/11 (153).tif[0].docx
#   inflating: out_pages/single/11 (153).tif[0].txt
#   inflating: out_pages/single/11 (154).tif[0].docx
#   inflating: out_pages/single/11 (154).tif[0].txt
#   inflating: out_pages/single/11 (155).tif[0].docx
#   inflating: out_pages/single/11 (155).tif[0].txt
#   inflating: out_pages/single/11 (156).tif[0].docx
#   inflating: out_pages/single/11 (156).tif[0].txt
#   inflating: out_pages/single/11 (157).tif[0].docx
#   inflating: out_pages/single/11 (157).tif[0].txt
#   inflating: out_pages/single/11 (158).tif[0].docx
#   inflating: out_pages/single/11 (158).tif[0].txt
#   inflating: out_pages/single/11 (159).tif[0].docx
#   inflating: out_pages/single/11 (159).tif[0].txt
#   inflating: out_pages/single/11 (16).tif[0].docx
#   inflating: out_pages/single/11 (16).tif[0].txt
#   inflating: out_pages/single/11 (160).tif[0].docx
#   inflating: out_pages/single/11 (160).tif[0].txt
#   inflating: out_pages/single/11 (161).tif[0].docx
#   inflating: out_pages/single/11 (161).tif[0].txt
#   inflating: out_pages/single/11 (162).tif[0].docx
#   inflating: out_pages/single/11 (162).tif[0].txt
#   inflating: out_pages/single/11 (163).tif[0].docx
#   inflating: out_pages/single/11 (163).tif[0].txt
#   inflating: out_pages/single/11 (164).tif[0].docx
#   inflating: out_pages/single/11 (164).tif[0].txt
#   inflating: out_pages/single/11 (165).tif[0].docx
#   inflating: out_pages/single/11 (165).tif[0].txt
#   inflating: out_pages/single/11 (166).tif[0].docx
#   inflating: out_pages/single/11 (166).tif[0].txt
#   inflating: out_pages/single/11 (167).tif[0].docx
#   inflating: out_pages/single/11 (167).tif[0].txt
#   inflating: out_pages/single/11 (168).tif[0].docx
#   inflating: out_pages/single/11 (168).tif[0].txt
#   inflating: out_pages/single/11 (169).tif[0].docx
#   inflating: out_pages/single/11 (169).tif[0].txt
#   inflating: out_pages/single/11 (17).tif[0].docx
#   inflating: out_pages/single/11 (17).tif[0].txt
#   inflating: out_pages/single/11 (170).tif[0].docx
#   inflating: out_pages/single/11 (170).tif[0].txt
#   inflating: out_pages/single/11 (171).tif[0].docx
#   inflating: out_pages/single/11 (171).tif[0].txt
#   inflating: out_pages/single/11 (172).tif[0].docx
#   inflating: out_pages/single/11 (172).tif[0].txt
#   inflating: out_pages/single/11 (173).tif[0].docx
#   inflating: out_pages/single/11 (173).tif[0].txt
#   inflating: out_pages/single/11 (174).tif[0].docx
#   inflating: out_pages/single/11 (174).tif[0].txt
#   inflating: out_pages/single/11 (175).tif[0].docx
#   inflating: out_pages/single/11 (175).tif[0].txt
#   inflating: out_pages/single/11 (176).tif[0].docx
#   inflating: out_pages/single/11 (176).tif[0].txt
#   inflating: out_pages/single/11 (177).tif[0].docx
#   inflating: out_pages/single/11 (177).tif[0].txt
#   inflating: out_pages/single/11 (178).tif[0].docx
#   inflating: out_pages/single/11 (178).tif[0].txt
#   inflating: out_pages/single/11 (179).tif[0].docx
#   inflating: out_pages/single/11 (179).tif[0].txt
#   inflating: out_pages/single/11 (18).tif[0].docx
#   inflating: out_pages/single/11 (18).tif[0].txt
#   inflating: out_pages/single/11 (180).tif[0].docx
#   inflating: out_pages/single/11 (180).tif[0].txt
#   inflating: out_pages/single/11 (181).tif[0].docx
#   inflating: out_pages/single/11 (181).tif[0].txt
#   inflating: out_pages/single/11 (182).tif[0].docx
#   inflating: out_pages/single/11 (182).tif[0].txt
#   inflating: out_pages/single/11 (183).tif[0].docx
#   inflating: out_pages/single/11 (183).tif[0].txt
#   inflating: out_pages/single/11 (184).tif[0].docx
#   inflating: out_pages/single/11 (184).tif[0].txt
#   inflating: out_pages/single/11 (185).tif[0].docx
#   inflating: out_pages/single/11 (185).tif[0].txt
#   inflating: out_pages/single/11 (186).tif[0].docx
#   inflating: out_pages/single/11 (186).tif[0].txt
#   inflating: out_pages/single/11 (187).tif[0].docx
#   inflating: out_pages/single/11 (187).tif[0].txt
#   inflating: out_pages/single/11 (188).tif[0].docx
#   inflating: out_pages/single/11 (188).tif[0].txt
#   inflating: out_pages/single/11 (189).tif[0].docx
#   inflating: out_pages/single/11 (189).tif[0].txt
#   inflating: out_pages/single/11 (19).tif[0].docx
#   inflating: out_pages/single/11 (19).tif[0].txt
#   inflating: out_pages/single/11 (191).tif[0].docx
#   inflating: out_pages/single/11 (191).tif[0].txt
#   inflating: out_pages/single/11 (192).tif[0].docx
#   inflating: out_pages/single/11 (192).tif[0].txt
#   inflating: out_pages/single/11 (193).tif[0].docx
#   inflating: out_pages/single/11 (193).tif[0].txt
#   inflating: out_pages/single/11 (194).tif[0].docx
#   inflating: out_pages/single/11 (194).tif[0].txt
#   inflating: out_pages/single/11 (195).tif[0].docx
#   inflating: out_pages/single/11 (195).tif[0].txt
#   inflating: out_pages/single/11 (196).tif[0].docx
#   inflating: out_pages/single/11 (196).tif[0].txt
#   inflating: out_pages/single/11 (197).tif[0].docx
#   inflating: out_pages/single/11 (197).tif[0].txt
#   inflating: out_pages/single/11 (198).tif[0].docx
#   inflating: out_pages/single/11 (198).tif[0].txt
#   inflating: out_pages/single/11 (199).tif[0].docx
#   inflating: out_pages/single/11 (199).tif[0].txt
#   inflating: out_pages/single/11 (2).tif[0].docx
#   inflating: out_pages/single/11 (2).tif[0].txt
#   inflating: out_pages/single/11 (20).tif[0].docx
#   inflating: out_pages/single/11 (20).tif[0].txt
#   inflating: out_pages/single/11 (200).tif[0].docx
#   inflating: out_pages/single/11 (200).tif[0].txt
#   inflating: out_pages/single/11 (201).tif[0].docx
#   inflating: out_pages/single/11 (201).tif[0].txt
#   inflating: out_pages/single/11 (202).tif[0].docx
#   inflating: out_pages/single/11 (202).tif[0].txt
#   inflating: out_pages/single/11 (204).tif[0].docx
#   inflating: out_pages/single/11 (204).tif[0].txt
#   inflating: out_pages/single/11 (205).tif[0].docx
#   inflating: out_pages/single/11 (205).tif[0].txt
#   inflating: out_pages/single/11 (206).tif[0].docx
#   inflating: out_pages/single/11 (206).tif[0].txt
#   inflating: out_pages/single/11 (207).tif[0].docx
#   inflating: out_pages/single/11 (207).tif[0].txt
#   inflating: out_pages/single/11 (208).tif[0].docx
#   inflating: out_pages/single/11 (208).tif[0].txt
#   inflating: out_pages/single/11 (209).tif[0].docx
#   inflating: out_pages/single/11 (209).tif[0].txt
#   inflating: out_pages/single/11 (21).tif[0].docx
#   inflating: out_pages/single/11 (21).tif[0].txt
#   inflating: out_pages/single/11 (210).tif[0].docx
#   inflating: out_pages/single/11 (210).tif[0].txt
#   inflating: out_pages/single/11 (211).tif[0].docx
#   inflating: out_pages/single/11 (211).tif[0].txt
#   inflating: out_pages/single/11 (212).tif[0].docx
#   inflating: out_pages/single/11 (212).tif[0].txt
#   inflating: out_pages/single/11 (213).tif[0].docx
#   inflating: out_pages/single/11 (213).tif[0].txt
#   inflating: out_pages/single/11 (214).tif[0].docx
#   inflating: out_pages/single/11 (214).tif[0].txt
#   inflating: out_pages/single/11 (215).tif[0].docx
#   inflating: out_pages/single/11 (215).tif[0].txt
#   inflating: out_pages/single/11 (216).tif[0].docx
#   inflating: out_pages/single/11 (216).tif[0].txt
#   inflating: out_pages/single/11 (217).tif[0].docx
#   inflating: out_pages/single/11 (217).tif[0].txt
#   inflating: out_pages/single/11 (218).tif[0].docx
#   inflating: out_pages/single/11 (218).tif[0].txt
#   inflating: out_pages/single/11 (219).tif[0].docx
#   inflating: out_pages/single/11 (219).tif[0].txt
#   inflating: out_pages/single/11 (220).tif[0].docx
#   inflating: out_pages/single/11 (220).tif[0].txt
#   inflating: out_pages/single/11 (221).tif[0].docx
#   inflating: out_pages/single/11 (221).tif[0].txt
#   inflating: out_pages/single/11 (222).tif[0].docx
#   inflating: out_pages/single/11 (222).tif[0].txt
#   inflating: out_pages/single/11 (223).tif[0].docx
#   inflating: out_pages/single/11 (223).tif[0].txt
#   inflating: out_pages/single/11 (224).tif[0].docx
#   inflating: out_pages/single/11 (224).tif[0].txt
#   inflating: out_pages/single/11 (225).tif[0].docx
#   inflating: out_pages/single/11 (225).tif[0].txt
#   inflating: out_pages/single/11 (226).tif[0].docx
#   inflating: out_pages/single/11 (226).tif[0].txt
#   inflating: out_pages/single/11 (227).tif[0].docx
#   inflating: out_pages/single/11 (227).tif[0].txt
#   inflating: out_pages/single/11 (228).tif[0].docx
#   inflating: out_pages/single/11 (228).tif[0].txt
#   inflating: out_pages/single/11 (229).tif[0].docx
#   inflating: out_pages/single/11 (229).tif[0].txt
#   inflating: out_pages/single/11 (23).tif[0].docx
#   inflating: out_pages/single/11 (23).tif[0].txt
#   inflating: out_pages/single/11 (230).tif[0].docx
#   inflating: out_pages/single/11 (230).tif[0].txt
#   inflating: out_pages/single/11 (231).tif[0].docx
#   inflating: out_pages/single/11 (231).tif[0].txt
#   inflating: out_pages/single/11 (232).tif[0].docx
#   inflating: out_pages/single/11 (232).tif[0].txt
#   inflating: out_pages/single/11 (233).tif[0].docx
#   inflating: out_pages/single/11 (233).tif[0].txt
#   inflating: out_pages/single/11 (234).tif[0].docx
#   inflating: out_pages/single/11 (234).tif[0].txt
#   inflating: out_pages/single/11 (235).tif[0].docx
#   inflating: out_pages/single/11 (235).tif[0].txt
#   inflating: out_pages/single/11 (236).tif[0].docx
#   inflating: out_pages/single/11 (236).tif[0].txt
#   inflating: out_pages/single/11 (237).tif[0].docx
#   inflating: out_pages/single/11 (237).tif[0].txt
#   inflating: out_pages/single/11 (238).tif[0].docx
#   inflating: out_pages/single/11 (238).tif[0].txt
#   inflating: out_pages/single/11 (239).tif[0].docx
#   inflating: out_pages/single/11 (239).tif[0].txt
#   inflating: out_pages/single/11 (24).tif[0].docx
#   inflating: out_pages/single/11 (24).tif[0].txt
#   inflating: out_pages/single/11 (240).tif[0].docx
#   inflating: out_pages/single/11 (240).tif[0].txt
#   inflating: out_pages/single/11 (241).tif[0].docx
#   inflating: out_pages/single/11 (241).tif[0].txt
#   inflating: out_pages/single/11 (242).tif[0].docx
#   inflating: out_pages/single/11 (242).tif[0].txt
#   inflating: out_pages/single/11 (243).tif[0].docx
#   inflating: out_pages/single/11 (243).tif[0].txt
#   inflating: out_pages/single/11 (244).tif[0].docx
#   inflating: out_pages/single/11 (244).tif[0].txt
#   inflating: out_pages/single/11 (245).tif[0].docx
#   inflating: out_pages/single/11 (245).tif[0].txt
#   inflating: out_pages/single/11 (246).tif[0].docx
#   inflating: out_pages/single/11 (246).tif[0].txt
#   inflating: out_pages/single/11 (247).tif[0].docx
#   inflating: out_pages/single/11 (247).tif[0].txt
#   inflating: out_pages/single/11 (248).tif[0].docx
#   inflating: out_pages/single/11 (248).tif[0].txt
#   inflating: out_pages/single/11 (249).tif[0].docx
#   inflating: out_pages/single/11 (249).tif[0].txt
#   inflating: out_pages/single/11 (25).tif[0].docx
#   inflating: out_pages/single/11 (25).tif[0].txt
#   inflating: out_pages/single/11 (250).tif[0].docx
#   inflating: out_pages/single/11 (250).tif[0].txt
#   inflating: out_pages/single/11 (251).tif[0].docx
#   inflating: out_pages/single/11 (251).tif[0].txt
#   inflating: out_pages/single/11 (252).tif[0].docx
#   inflating: out_pages/single/11 (252).tif[0].txt
#   inflating: out_pages/single/11 (253).tif[0].docx
#   inflating: out_pages/single/11 (253).tif[0].txt
#   inflating: out_pages/single/11 (254).tif[0].docx
#   inflating: out_pages/single/11 (254).tif[0].txt
#   inflating: out_pages/single/11 (255).tif[0].docx
#   inflating: out_pages/single/11 (255).tif[0].txt
#   inflating: out_pages/single/11 (256).tif[0].docx
#   inflating: out_pages/single/11 (256).tif[0].txt
#   inflating: out_pages/single/11 (257).tif[0].docx
#   inflating: out_pages/single/11 (257).tif[0].txt
#   inflating: out_pages/single/11 (258).tif[0].docx
#   inflating: out_pages/single/11 (258).tif[0].txt
#   inflating: out_pages/single/11 (259).tif[0].docx
#   inflating: out_pages/single/11 (259).tif[0].txt
#   inflating: out_pages/single/11 (26).tif[0].docx
#   inflating: out_pages/single/11 (26).tif[0].txt
#   inflating: out_pages/single/11 (260).tif[0].docx
#   inflating: out_pages/single/11 (260).tif[0].txt
#   inflating: out_pages/single/11 (261).tif[0].docx
#   inflating: out_pages/single/11 (261).tif[0].txt
#   inflating: out_pages/single/11 (262).tif[0].docx
#   inflating: out_pages/single/11 (262).tif[0].txt
#   inflating: out_pages/single/11 (263).tif[0].docx
#   inflating: out_pages/single/11 (263).tif[0].txt
#   inflating: out_pages/single/11 (264).tif[0].docx
#   inflating: out_pages/single/11 (264).tif[0].txt
#   inflating: out_pages/single/11 (265).tif[0].docx
#   inflating: out_pages/single/11 (265).tif[0].txt
#   inflating: out_pages/single/11 (266).tif[0].docx
#   inflating: out_pages/single/11 (266).tif[0].txt
#   inflating: out_pages/single/11 (267).tif[0].docx
#   inflating: out_pages/single/11 (267).tif[0].txt
#   inflating: out_pages/single/11 (268).tif[0].docx
#   inflating: out_pages/single/11 (268).tif[0].txt
#   inflating: out_pages/single/11 (269).tif[0].docx
#   inflating: out_pages/single/11 (269).tif[0].txt
#   inflating: out_pages/single/11 (27).tif[0].docx
#   inflating: out_pages/single/11 (27).tif[0].txt
#   inflating: out_pages/single/11 (270).tif[0].docx
#   inflating: out_pages/single/11 (270).tif[0].txt
#   inflating: out_pages/single/11 (271).tif[0].docx
#   inflating: out_pages/single/11 (271).tif[0].txt
#   inflating: out_pages/single/11 (272).tif[0].docx
#   inflating: out_pages/single/11 (272).tif[0].txt
#   inflating: out_pages/single/11 (273).tif[0].docx
#   inflating: out_pages/single/11 (273).tif[0].txt
#   inflating: out_pages/single/11 (274).tif[0].docx
#   inflating: out_pages/single/11 (274).tif[0].txt
#   inflating: out_pages/single/11 (275).tif[0].docx
#   inflating: out_pages/single/11 (275).tif[0].txt
#   inflating: out_pages/single/11 (276).tif[0].docx
#   inflating: out_pages/single/11 (276).tif[0].txt
#   inflating: out_pages/single/11 (277).tif[0].docx
#   inflating: out_pages/single/11 (277).tif[0].txt
#   inflating: out_pages/single/11 (278).tif[0].docx
#   inflating: out_pages/single/11 (278).tif[0].txt
#   inflating: out_pages/single/11 (279).tif[0].docx
#   inflating: out_pages/single/11 (279).tif[0].txt
#   inflating: out_pages/single/11 (28).tif[0].docx
#   inflating: out_pages/single/11 (28).tif[0].txt
#   inflating: out_pages/single/11 (280).tif[0].docx
#   inflating: out_pages/single/11 (280).tif[0].txt
#   inflating: out_pages/single/11 (281).tif[0].docx
#   inflating: out_pages/single/11 (281).tif[0].txt
#   inflating: out_pages/single/11 (282).tif[0].docx
#   inflating: out_pages/single/11 (282).tif[0].txt
#   inflating: out_pages/single/11 (283).tif[0].docx
#   inflating: out_pages/single/11 (283).tif[0].txt
#   inflating: out_pages/single/11 (284).tif[0].docx
#   inflating: out_pages/single/11 (284).tif[0].txt
#   inflating: out_pages/single/11 (285).tif[0].docx
#   inflating: out_pages/single/11 (285).tif[0].txt
#   inflating: out_pages/single/11 (286).tif[0].docx
#   inflating: out_pages/single/11 (286).tif[0].txt
#   inflating: out_pages/single/11 (287).tif[0].docx
#   inflating: out_pages/single/11 (287).tif[0].txt
#   inflating: out_pages/single/11 (288).tif[0].docx
#   inflating: out_pages/single/11 (288).tif[0].txt
#   inflating: out_pages/single/11 (289).tif[0].docx
#   inflating: out_pages/single/11 (289).tif[0].txt
#   inflating: out_pages/single/11 (29).tif[0].docx
#   inflating: out_pages/single/11 (29).tif[0].txt
#   inflating: out_pages/single/11 (290).tif[0].docx
#   inflating: out_pages/single/11 (290).tif[0].txt
#   inflating: out_pages/single/11 (291).tif[0].docx
#   inflating: out_pages/single/11 (291).tif[0].txt
#   inflating: out_pages/single/11 (293).tif[0].docx
#   inflating: out_pages/single/11 (293).tif[0].txt
#   inflating: out_pages/single/11 (294).tif[0].docx
#   inflating: out_pages/single/11 (294).tif[0].txt
#   inflating: out_pages/single/11 (295).tif[0].docx
#   inflating: out_pages/single/11 (295).tif[0].txt
#   inflating: out_pages/single/11 (296).tif[0].docx
#   inflating: out_pages/single/11 (296).tif[0].txt
#   inflating: out_pages/single/11 (297).tif[0].docx
#   inflating: out_pages/single/11 (297).tif[0].txt
#   inflating: out_pages/single/11 (298).tif[0].docx
#   inflating: out_pages/single/11 (298).tif[0].txt
#   inflating: out_pages/single/11 (299).tif[0].docx
#   inflating: out_pages/single/11 (299).tif[0].txt
#   inflating: out_pages/single/11 (3).tif[0].docx
#   inflating: out_pages/single/11 (3).tif[0].txt
#   inflating: out_pages/single/11 (30).tif[0].docx
#   inflating: out_pages/single/11 (30).tif[0].txt
#   inflating: out_pages/single/11 (300).tif[0].docx
#   inflating: out_pages/single/11 (300).tif[0].txt
#   inflating: out_pages/single/11 (301).tif[0].docx
#   inflating: out_pages/single/11 (301).tif[0].txt
#   inflating: out_pages/single/11 (302).tif[0].docx
#   inflating: out_pages/single/11 (302).tif[0].txt
#   inflating: out_pages/single/11 (303).tif[0].docx
#   inflating: out_pages/single/11 (303).tif[0].txt
#   inflating: out_pages/single/11 (304).tif[0].docx
#   inflating: out_pages/single/11 (304).tif[0].txt
#   inflating: out_pages/single/11 (305).tif[0].docx
#   inflating: out_pages/single/11 (305).tif[0].txt
#   inflating: out_pages/single/11 (306).tif[0].docx
#   inflating: out_pages/single/11 (306).tif[0].txt
#   inflating: out_pages/single/11 (308).tif[0].docx
#   inflating: out_pages/single/11 (308).tif[0].txt
#   inflating: out_pages/single/11 (309).tif[0].docx
#   inflating: out_pages/single/11 (309).tif[0].txt
#   inflating: out_pages/single/11 (31).tif[0].docx
#   inflating: out_pages/single/11 (31).tif[0].txt
#   inflating: out_pages/single/11 (310).tif[0].docx
#   inflating: out_pages/single/11 (310).tif[0].txt
#   inflating: out_pages/single/11 (311).tif[0].docx
#   inflating: out_pages/single/11 (311).tif[0].txt
#   inflating: out_pages/single/11 (312).tif[0].docx
#   inflating: out_pages/single/11 (312).tif[0].txt
#   inflating: out_pages/single/11 (313).tif[0].docx
#   inflating: out_pages/single/11 (313).tif[0].txt
#   inflating: out_pages/single/11 (314).tif[0].docx
#   inflating: out_pages/single/11 (314).tif[0].txt
#   inflating: out_pages/single/11 (315).tif[0].docx
#   inflating: out_pages/single/11 (315).tif[0].txt
#   inflating: out_pages/single/11 (316).tif[0].docx
#   inflating: out_pages/single/11 (316).tif[0].txt
#   inflating: out_pages/single/11 (317).tif[0].docx
#   inflating: out_pages/single/11 (317).tif[0].txt
#   inflating: out_pages/single/11 (318).tif[0].docx
#   inflating: out_pages/single/11 (318).tif[0].txt
#   inflating: out_pages/single/11 (319).tif[0].docx
#   inflating: out_pages/single/11 (319).tif[0].txt
#   inflating: out_pages/single/11 (32).tif[0].docx
#   inflating: out_pages/single/11 (32).tif[0].txt
#   inflating: out_pages/single/11 (320).tif[0].docx
#   inflating: out_pages/single/11 (320).tif[0].txt
#   inflating: out_pages/single/11 (321).tif[0].docx
#   inflating: out_pages/single/11 (321).tif[0].txt
#   inflating: out_pages/single/11 (322).tif[0].docx
#   inflating: out_pages/single/11 (322).tif[0].txt
#   inflating: out_pages/single/11 (323).tif[0].docx
#   inflating: out_pages/single/11 (323).tif[0].txt
#   inflating: out_pages/single/11 (324).tif[0].docx
#   inflating: out_pages/single/11 (324).tif[0].txt
#   inflating: out_pages/single/11 (325).tif[0].docx
#   inflating: out_pages/single/11 (325).tif[0].txt
#   inflating: out_pages/single/11 (326).tif[0].docx
#   inflating: out_pages/single/11 (326).tif[0].txt
#   inflating: out_pages/single/11 (327).tif[0].docx
#   inflating: out_pages/single/11 (327).tif[0].txt
#   inflating: out_pages/single/11 (328).tif[0].docx
#   inflating: out_pages/single/11 (328).tif[0].txt
#   inflating: out_pages/single/11 (329).tif[0].docx
#   inflating: out_pages/single/11 (329).tif[0].txt
#   inflating: out_pages/single/11 (33).tif[0].docx
#   inflating: out_pages/single/11 (33).tif[0].txt
#   inflating: out_pages/single/11 (330).tif[0].docx
#   inflating: out_pages/single/11 (330).tif[0].txt
#   inflating: out_pages/single/11 (331).tif[0].docx
#   inflating: out_pages/single/11 (331).tif[0].txt
#   inflating: out_pages/single/11 (332).tif[0].docx
#   inflating: out_pages/single/11 (332).tif[0].txt
#   inflating: out_pages/single/11 (333).tif[0].docx
#   inflating: out_pages/single/11 (333).tif[0].txt
#   inflating: out_pages/single/11 (335).tif[0].docx
#   inflating: out_pages/single/11 (335).tif[0].txt
#   inflating: out_pages/single/11 (336).tif[0].docx
#   inflating: out_pages/single/11 (336).tif[0].txt
#   inflating: out_pages/single/11 (338).tif[0].docx
#   inflating: out_pages/single/11 (338).tif[0].txt
#   inflating: out_pages/single/11 (339).tif[0].docx
#   inflating: out_pages/single/11 (339).tif[0].txt
#   inflating: out_pages/single/11 (34).tif[0].docx
#   inflating: out_pages/single/11 (34).tif[0].txt
#   inflating: out_pages/single/11 (340).tif[0].docx
#   inflating: out_pages/single/11 (340).tif[0].txt
#   inflating: out_pages/single/11 (341).tif[0].docx
#   inflating: out_pages/single/11 (341).tif[0].txt
#   inflating: out_pages/single/11 (342).tif[0].docx
#   inflating: out_pages/single/11 (342).tif[0].txt
#   inflating: out_pages/single/11 (343).tif[0].docx
#   inflating: out_pages/single/11 (343).tif[0].txt
#   inflating: out_pages/single/11 (345).tif[0].docx
#   inflating: out_pages/single/11 (345).tif[0].txt
#   inflating: out_pages/single/11 (346).tif[0].docx
#   inflating: out_pages/single/11 (346).tif[0].txt
#   inflating: out_pages/single/11 (347).tif[0].docx
#   inflating: out_pages/single/11 (347).tif[0].txt
#   inflating: out_pages/single/11 (348).tif[0].docx
#   inflating: out_pages/single/11 (348).tif[0].txt
#   inflating: out_pages/single/11 (349).tif[0].docx
#   inflating: out_pages/single/11 (349).tif[0].txt
#   inflating: out_pages/single/11 (35).tif[0].docx
#   inflating: out_pages/single/11 (35).tif[0].txt
#   inflating: out_pages/single/11 (350).tif[0].docx
#   inflating: out_pages/single/11 (350).tif[0].txt
#   inflating: out_pages/single/11 (351).tif[0].docx
#   inflating: out_pages/single/11 (351).tif[0].txt
#   inflating: out_pages/single/11 (352).tif[0].docx
#   inflating: out_pages/single/11 (352).tif[0].txt
#   inflating: out_pages/single/11 (353).tif[0].docx
#   inflating: out_pages/single/11 (353).tif[0].txt
#   inflating: out_pages/single/11 (354).tif[0].docx
#   inflating: out_pages/single/11 (354).tif[0].txt
#   inflating: out_pages/single/11 (355).tif[0].docx
#   inflating: out_pages/single/11 (355).tif[0].txt
#   inflating: out_pages/single/11 (356).tif[0].docx
#   inflating: out_pages/single/11 (356).tif[0].txt
#   inflating: out_pages/single/11 (357).tif[0].docx
#   inflating: out_pages/single/11 (357).tif[0].txt
#   inflating: out_pages/single/11 (358).tif[0].docx
#   inflating: out_pages/single/11 (358).tif[0].txt
#   inflating: out_pages/single/11 (359).tif[0].docx
#   inflating: out_pages/single/11 (359).tif[0].txt
#   inflating: out_pages/single/11 (36).tif[0].docx
#   inflating: out_pages/single/11 (36).tif[0].txt
#   inflating: out_pages/single/11 (362).tif[0].docx
#   inflating: out_pages/single/11 (362).tif[0].txt
#   inflating: out_pages/single/11 (364).tif[0].docx
#   inflating: out_pages/single/11 (364).tif[0].txt
#   inflating: out_pages/single/11 (366).tif[0].docx
#   inflating: out_pages/single/11 (366).tif[0].txt
#   inflating: out_pages/single/11 (367).tif[0].docx
#   inflating: out_pages/single/11 (367).tif[0].txt
#   inflating: out_pages/single/11 (368).tif[0].docx
#   inflating: out_pages/single/11 (368).tif[0].txt
#   inflating: out_pages/single/11 (369).tif[0].docx
#   inflating: out_pages/single/11 (369).tif[0].txt
#   inflating: out_pages/single/11 (37).tif[0].docx
#   inflating: out_pages/single/11 (37).tif[0].txt
#   inflating: out_pages/single/11 (370).tif[0].docx
#   inflating: out_pages/single/11 (370).tif[0].txt
#   inflating: out_pages/single/11 (371).tif[0].docx
#   inflating: out_pages/single/11 (371).tif[0].txt
#   inflating: out_pages/single/11 (373).tif[0].docx
#   inflating: out_pages/single/11 (373).tif[0].txt
#   inflating: out_pages/single/11 (374).tif[0].docx
#   inflating: out_pages/single/11 (374).tif[0].txt
#   inflating: out_pages/single/11 (375).tif[0].docx
#   inflating: out_pages/single/11 (375).tif[0].txt
#   inflating: out_pages/single/11 (376).tif[0].docx
#   inflating: out_pages/single/11 (376).tif[0].txt
#   inflating: out_pages/single/11 (377).tif[0].docx
#   inflating: out_pages/single/11 (377).tif[0].txt
#   inflating: out_pages/single/11 (378).tif[0].docx
#   inflating: out_pages/single/11 (378).tif[0].txt
#   inflating: out_pages/single/11 (38).tif[0].docx
#   inflating: out_pages/single/11 (38).tif[0].txt
#   inflating: out_pages/single/11 (380).tif[0].docx
#   inflating: out_pages/single/11 (380).tif[0].txt
#   inflating: out_pages/single/11 (381).tif[0].docx
#   inflating: out_pages/single/11 (381).tif[0].txt
#   inflating: out_pages/single/11 (383).tif[0].docx
#   inflating: out_pages/single/11 (383).tif[0].txt
#   inflating: out_pages/single/11 (384).tif[0].docx
#   inflating: out_pages/single/11 (384).tif[0].txt
#   inflating: out_pages/single/11 (385).tif[0].docx
#   inflating: out_pages/single/11 (385).tif[0].txt
#   inflating: out_pages/single/11 (386).tif[0].docx
#   inflating: out_pages/single/11 (386).tif[0].txt
#   inflating: out_pages/single/11 (387).tif[0].docx
#   inflating: out_pages/single/11 (387).tif[0].txt
#   inflating: out_pages/single/11 (388).tif[0].docx
#   inflating: out_pages/single/11 (388).tif[0].txt
#   inflating: out_pages/single/11 (39).tif[0].docx
#   inflating: out_pages/single/11 (39).tif[0].txt
#   inflating: out_pages/single/11 (390).tif[0].docx
#   inflating: out_pages/single/11 (390).tif[0].txt
#   inflating: out_pages/single/11 (392).tif[0].docx
#   inflating: out_pages/single/11 (392).tif[0].txt
#   inflating: out_pages/single/11 (393).tif[0].docx
#   inflating: out_pages/single/11 (393).tif[0].txt
#   inflating: out_pages/single/11 (394).tif[0].docx
#   inflating: out_pages/single/11 (394).tif[0].txt
#   inflating: out_pages/single/11 (395).tif[0].docx
#   inflating: out_pages/single/11 (395).tif[0].txt
#   inflating: out_pages/single/11 (396).tif[0].docx
#   inflating: out_pages/single/11 (396).tif[0].txt
#   inflating: out_pages/single/11 (397).tif[0].docx
#   inflating: out_pages/single/11 (397).tif[0].txt
#   inflating: out_pages/single/11 (399).tif[0].docx
#   inflating: out_pages/single/11 (399).tif[0].txt
#   inflating: out_pages/single/11 (4).tif[0].docx
#   inflating: out_pages/single/11 (4).tif[0].txt
#   inflating: out_pages/single/11 (40).tif[0].docx
#   inflating: out_pages/single/11 (40).tif[0].txt
#   inflating: out_pages/single/11 (400).tif[0].docx
#   inflating: out_pages/single/11 (400).tif[0].txt
#   inflating: out_pages/single/11 (401).tif[0].docx
#   inflating: out_pages/single/11 (401).tif[0].txt
#   inflating: out_pages/single/11 (402).tif[0].docx
#   inflating: out_pages/single/11 (402).tif[0].txt
#   inflating: out_pages/single/11 (403).tif[0].docx
#   inflating: out_pages/single/11 (403).tif[0].txt
#   inflating: out_pages/single/11 (404).tif[0].docx
#   inflating: out_pages/single/11 (404).tif[0].txt
#   inflating: out_pages/single/11 (405).tif[0].docx
#   inflating: out_pages/single/11 (405).tif[0].txt
#   inflating: out_pages/single/11 (406).tif[0].docx
#   inflating: out_pages/single/11 (406).tif[0].txt
#   inflating: out_pages/single/11 (407).tif[0].docx
#   inflating: out_pages/single/11 (407).tif[0].txt
#   inflating: out_pages/single/11 (408).tif[0].docx
#   inflating: out_pages/single/11 (408).tif[0].txt
#   inflating: out_pages/single/11 (409).tif[0].docx
#   inflating: out_pages/single/11 (409).tif[0].txt
#   inflating: out_pages/single/11 (410).tif[0].docx
#   inflating: out_pages/single/11 (410).tif[0].txt
#   inflating: out_pages/single/11 (411).tif[0].docx
#   inflating: out_pages/single/11 (411).tif[0].txt
#   inflating: out_pages/single/11 (412).tif[0].docx
#   inflating: out_pages/single/11 (412).tif[0].txt
#   inflating: out_pages/single/11 (413).tif[0].docx
#   inflating: out_pages/single/11 (413).tif[0].txt
#   inflating: out_pages/single/11 (414).tif[0].docx
#   inflating: out_pages/single/11 (414).tif[0].txt
#   inflating: out_pages/single/11 (415).tif[0].docx
#   inflating: out_pages/single/11 (415).tif[0].txt
#   inflating: out_pages/single/11 (416).tif[0].docx
#   inflating: out_pages/single/11 (416).tif[0].txt
#   inflating: out_pages/single/11 (417).tif[0].docx
#   inflating: out_pages/single/11 (417).tif[0].txt
#   inflating: out_pages/single/11 (418).tif[0].docx
#   inflating: out_pages/single/11 (418).tif[0].txt
#   inflating: out_pages/single/11 (419).tif[0].docx
#   inflating: out_pages/single/11 (419).tif[0].txt
#   inflating: out_pages/single/11 (42).tif[0].docx
#   inflating: out_pages/single/11 (42).tif[0].txt
#   inflating: out_pages/single/11 (420).tif[0].docx
#   inflating: out_pages/single/11 (420).tif[0].txt
#   inflating: out_pages/single/11 (421).tif[0].docx
#   inflating: out_pages/single/11 (421).tif[0].txt
#   inflating: out_pages/single/11 (422).tif[0].docx
#   inflating: out_pages/single/11 (422).tif[0].txt
#   inflating: out_pages/single/11 (423).tif[0].docx
#   inflating: out_pages/single/11 (423).tif[0].txt
#   inflating: out_pages/single/11 (424).tif[0].docx
#   inflating: out_pages/single/11 (424).tif[0].txt
#   inflating: out_pages/single/11 (426).tif[0].docx
#   inflating: out_pages/single/11 (426).tif[0].txt
#   inflating: out_pages/single/11 (427).tif[0].docx
#   inflating: out_pages/single/11 (427).tif[0].txt
#   inflating: out_pages/single/11 (428).tif[0].docx
#   inflating: out_pages/single/11 (428).tif[0].txt
#   inflating: out_pages/single/11 (429).tif[0].docx
#   inflating: out_pages/single/11 (429).tif[0].txt
#   inflating: out_pages/single/11 (43).tif[0].docx
#   inflating: out_pages/single/11 (43).tif[0].txt
#   inflating: out_pages/single/11 (430).tif[0].docx
#   inflating: out_pages/single/11 (430).tif[0].txt
#   inflating: out_pages/single/11 (431).tif[0].docx
#   inflating: out_pages/single/11 (431).tif[0].txt
#   inflating: out_pages/single/11 (432).tif[0].docx
#   inflating: out_pages/single/11 (432).tif[0].txt
#   inflating: out_pages/single/11 (433).tif[0].docx
#   inflating: out_pages/single/11 (433).tif[0].txt
#   inflating: out_pages/single/11 (434).tif[0].docx
#   inflating: out_pages/single/11 (434).tif[0].txt
#   inflating: out_pages/single/11 (435).tif[0].docx
#   inflating: out_pages/single/11 (435).tif[0].txt
#   inflating: out_pages/single/11 (436).tif[0].docx
#   inflating: out_pages/single/11 (436).tif[0].txt
#   inflating: out_pages/single/11 (437).tif[0].docx
#   inflating: out_pages/single/11 (437).tif[0].txt
#   inflating: out_pages/single/11 (438).tif[0].docx
#   inflating: out_pages/single/11 (438).tif[0].txt
#   inflating: out_pages/single/11 (439).tif[0].docx
#   inflating: out_pages/single/11 (439).tif[0].txt
#   inflating: out_pages/single/11 (44).tif[0].docx
#   inflating: out_pages/single/11 (44).tif[0].txt
#   inflating: out_pages/single/11 (440).tif[0].docx
#   inflating: out_pages/single/11 (440).tif[0].txt
#   inflating: out_pages/single/11 (441).tif[0].docx
#   inflating: out_pages/single/11 (441).tif[0].txt
#   inflating: out_pages/single/11 (442).tif[0].docx
#   inflating: out_pages/single/11 (442).tif[0].txt
#   inflating: out_pages/single/11 (443).tif[0].docx
#   inflating: out_pages/single/11 (443).tif[0].txt
#   inflating: out_pages/single/11 (444).tif[0].docx
#   inflating: out_pages/single/11 (444).tif[0].txt
#   inflating: out_pages/single/11 (445).tif[0].docx
#   inflating: out_pages/single/11 (445).tif[0].txt
#   inflating: out_pages/single/11 (447).tif[0].docx
#   inflating: out_pages/single/11 (447).tif[0].txt
#   inflating: out_pages/single/11 (448).tif[0].docx
#   inflating: out_pages/single/11 (448).tif[0].txt
#   inflating: out_pages/single/11 (449).tif[0].docx
#   inflating: out_pages/single/11 (449).tif[0].txt
#   inflating: out_pages/single/11 (45).tif[0].docx
#   inflating: out_pages/single/11 (45).tif[0].txt
#   inflating: out_pages/single/11 (450).tif[0].docx
#   inflating: out_pages/single/11 (450).tif[0].txt
#   inflating: out_pages/single/11 (451).tif[0].docx
#   inflating: out_pages/single/11 (451).tif[0].txt
#   inflating: out_pages/single/11 (452).tif[0].docx
#   inflating: out_pages/single/11 (452).tif[0].txt
#   inflating: out_pages/single/11 (453).tif[0].docx
#   inflating: out_pages/single/11 (453).tif[0].txt
#   inflating: out_pages/single/11 (454).tif[0].docx
#   inflating: out_pages/single/11 (454).tif[0].txt
#   inflating: out_pages/single/11 (455).tif[0].docx
#   inflating: out_pages/single/11 (455).tif[0].txt
#   inflating: out_pages/single/11 (456).tif[0].docx
#   inflating: out_pages/single/11 (456).tif[0].txt
#   inflating: out_pages/single/11 (457).tif[0].docx
#   inflating: out_pages/single/11 (457).tif[0].txt
#   inflating: out_pages/single/11 (458).tif[0].docx
#   inflating: out_pages/single/11 (458).tif[0].txt
#   inflating: out_pages/single/11 (459).tif[0].docx
#   inflating: out_pages/single/11 (459).tif[0].txt
#   inflating: out_pages/single/11 (46).tif[0].docx
#   inflating: out_pages/single/11 (46).tif[0].txt
#   inflating: out_pages/single/11 (460).tif[0].docx
#   inflating: out_pages/single/11 (460).tif[0].txt
#   inflating: out_pages/single/11 (461).tif[0].docx
#   inflating: out_pages/single/11 (461).tif[0].txt
#   inflating: out_pages/single/11 (462).tif[0].docx
#   inflating: out_pages/single/11 (462).tif[0].txt
#   inflating: out_pages/single/11 (463).tif[0].docx
#   inflating: out_pages/single/11 (463).tif[0].txt
#   inflating: out_pages/single/11 (464).tif[0].docx
#   inflating: out_pages/single/11 (464).tif[0].txt
#   inflating: out_pages/single/11 (465).tif[0].docx
#   inflating: out_pages/single/11 (465).tif[0].txt
#   inflating: out_pages/single/11 (466).tif[0].docx
#   inflating: out_pages/single/11 (466).tif[0].txt
#   inflating: out_pages/single/11 (467).tif[0].docx
#   inflating: out_pages/single/11 (467).tif[0].txt
#   inflating: out_pages/single/11 (468).tif[0].docx
#   inflating: out_pages/single/11 (468).tif[0].txt
#   inflating: out_pages/single/11 (469).tif[0].docx
#   inflating: out_pages/single/11 (469).tif[0].txt
#   inflating: out_pages/single/11 (47).tif[0].docx
#   inflating: out_pages/single/11 (47).tif[0].txt
#   inflating: out_pages/single/11 (470).tif[0].docx
#   inflating: out_pages/single/11 (470).tif[0].txt
#   inflating: out_pages/single/11 (471).tif[0].docx
#   inflating: out_pages/single/11 (471).tif[0].txt
#   inflating: out_pages/single/11 (472).tif[0].docx
#   inflating: out_pages/single/11 (472).tif[0].txt
#   inflating: out_pages/single/11 (473).tif[0].docx
#   inflating: out_pages/single/11 (473).tif[0].txt
#   inflating: out_pages/single/11 (474).tif[0].docx
#   inflating: out_pages/single/11 (474).tif[0].txt
#   inflating: out_pages/single/11 (475).tif[0].docx
#   inflating: out_pages/single/11 (475).tif[0].txt
#   inflating: out_pages/single/11 (476).tif[0].docx
#   inflating: out_pages/single/11 (476).tif[0].txt
#   inflating: out_pages/single/11 (477).tif[0].docx
#   inflating: out_pages/single/11 (477).tif[0].txt
#   inflating: out_pages/single/11 (478).tif[0].docx
#   inflating: out_pages/single/11 (478).tif[0].txt
#   inflating: out_pages/single/11 (479).tif[0].docx
#   inflating: out_pages/single/11 (479).tif[0].txt
#   inflating: out_pages/single/11 (48).tif[0].docx
#   inflating: out_pages/single/11 (48).tif[0].txt
#   inflating: out_pages/single/11 (480).tif[0].docx
#   inflating: out_pages/single/11 (480).tif[0].txt
#   inflating: out_pages/single/11 (481).tif[0].docx
#   inflating: out_pages/single/11 (481).tif[0].txt
#   inflating: out_pages/single/11 (482).tif[0].docx
#   inflating: out_pages/single/11 (482).tif[0].txt
#   inflating: out_pages/single/11 (484).tif[0].docx
#   inflating: out_pages/single/11 (484).tif[0].txt
#   inflating: out_pages/single/11 (485).tif[0].docx
#   inflating: out_pages/single/11 (485).tif[0].txt
#   inflating: out_pages/single/11 (486).tif[0].docx
#   inflating: out_pages/single/11 (486).tif[0].txt
#   inflating: out_pages/single/11 (487).tif[0].docx
#   inflating: out_pages/single/11 (487).tif[0].txt
#   inflating: out_pages/single/11 (489).tif[0].docx
#   inflating: out_pages/single/11 (489).tif[0].txt
#   inflating: out_pages/single/11 (49).tif[0].docx
#   inflating: out_pages/single/11 (49).tif[0].txt
#   inflating: out_pages/single/11 (490).tif[0].docx
#   inflating: out_pages/single/11 (490).tif[0].txt
#   inflating: out_pages/single/11 (491).tif[0].docx
#   inflating: out_pages/single/11 (491).tif[0].txt
#   inflating: out_pages/single/11 (493).tif[0].docx
#   inflating: out_pages/single/11 (493).tif[0].txt
#   inflating: out_pages/single/11 (494).tif[0].docx
#   inflating: out_pages/single/11 (494).tif[0].txt
#   inflating: out_pages/single/11 (495).tif[0].docx
#   inflating: out_pages/single/11 (495).tif[0].txt
#   inflating: out_pages/single/11 (496).tif[0].docx
#   inflating: out_pages/single/11 (496).tif[0].txt
#   inflating: out_pages/single/11 (5).tif[0].docx
#   inflating: out_pages/single/11 (5).tif[0].txt
# ...
#   inflating: out_pages/single/3 (290).tif[0].docx
#   inflating: out_pages/single/3 (290).tif[0].txt
#   inflating: out_pages/single/3 (291).tif[0].docx
#   inflating: out_pages/single/3 (291).tif[0].txt
#   inflating: out_pages/single/3 (292).tif[0].docx
#   inflating: out_pages/single/3 (292).tif[0].txt
#   inflating: out_pages/single/3 (293).tif[0].docx
#   inflating: out_pages/single/3 (293).tif[0].txt
#   inflating: out_pages/single/3 (294).tif[0].docx
#   inflating: out_pages/single/3 (294).tif[0].txt
#   inflating: out_pages/single/3 (295).tif[0].docx
#   inflating: out_pages/single/3 (295).tif[0].txt
#   inflating: out_pages/single/3 (297).tif[0].docx
#   inflating: out_pages/single/3 (297).tif[0].txt
#   inflating: out_pages/single/3 (298).tif[0].docx
#   inflating: out_pages/single/3 (298).tif[0].txt
#   inflating: out_pages/single/3 (299).tif[0].docx
#   inflating: out_pages/single/3 (299).tif[0].txt
#   inflating: out_pages/single/3 (3).tif[0].docx
#   inflating: out_pages/single/3 (3).tif[0].txt
#   inflating: out_pages/single/3 (30).tif[0].docx
#   inflating: out_pages/single/3 (30).tif[0].txt
#   inflating: out_pages/single/3 (300).tif[0].docx
#   inflating: out_pages/single/3 (300).tif[0].txt
#   inflating: out_pages/single/3 (301).tif[0].docx
#   inflating: out_pages/single/3 (301).tif[0].txt
#   inflating: out_pages/single/3 (302).tif[0].docx
#   inflating: out_pages/single/3 (302).tif[0].txt
#   inflating: out_pages/single/3 (303).tif[0].docx
#   inflating: out_pages/single/3 (303).tif[0].txt
#   inflating: out_pages/single/3 (304).tif[0].docx
#   inflating: out_pages/single/3 (304).tif[0].txt
#   inflating: out_pages/single/3 (305).tif[0].docx
#   inflating: out_pages/single/3 (305).tif[0].txt
#   inflating: out_pages/single/3 (306).tif[0].docx
#   inflating: out_pages/single/3 (306).tif[0].txt
#   inflating: out_pages/single/3 (307).tif[0].docx
#   inflating: out_pages/single/3 (307).tif[0].txt
#   inflating: out_pages/single/3 (308).tif[0].docx
#   inflating: out_pages/single/3 (308).tif[0].txt
#   inflating: out_pages/single/3 (309).tif[0].docx
#   inflating: out_pages/single/3 (309).tif[0].txt
#   inflating: out_pages/single/3 (31).tif[0].docx
#   inflating: out_pages/single/3 (31).tif[0].txt
#   inflating: out_pages/single/3 (310).tif[0].docx
#   inflating: out_pages/single/3 (310).tif[0].txt
#   inflating: out_pages/single/3 (311).tif[0].docx
#   inflating: out_pages/single/3 (311).tif[0].txt
#   inflating: out_pages/single/3 (312).tif[0].docx
#   inflating: out_pages/single/3 (312).tif[0].txt
#   inflating: out_pages/single/3 (313).tif[0].docx
#   inflating: out_pages/single/3 (313).tif[0].txt
#   inflating: out_pages/single/3 (314).tif[0].docx
#   inflating: out_pages/single/3 (314).tif[0].txt
#   inflating: out_pages/single/3 (315).tif[0].docx
#   inflating: out_pages/single/3 (315).tif[0].txt
#   inflating: out_pages/single/3 (316).tif[0].docx
#   inflating: out_pages/single/3 (316).tif[0].txt
#   inflating: out_pages/single/3 (317).tif[0].docx
#   inflating: out_pages/single/3 (317).tif[0].txt
#   inflating: out_pages/single/3 (318).tif[0].docx
#   inflating: out_pages/single/3 (318).tif[0].txt
#   inflating: out_pages/single/3 (319).tif[0].docx
#   inflating: out_pages/single/3 (319).tif[0].txt
#   inflating: out_pages/single/3 (32).tif[0].docx
#   inflating: out_pages/single/3 (32).tif[0].txt
#   inflating: out_pages/single/3 (320).tif[0].docx
#   inflating: out_pages/single/3 (320).tif[0].txt
#   inflating: out_pages/single/3 (321).tif[0].docx
#   inflating: out_pages/single/3 (321).tif[0].txt
#   inflating: out_pages/single/3 (322).tif[0].docx
#   inflating: out_pages/single/3 (322).tif[0].txt
#   inflating: out_pages/single/3 (323).tif[0].docx
#   inflating: out_pages/single/3 (323).tif[0].txt
#   inflating: out_pages/single/3 (324).tif[0].docx
#   inflating: out_pages/single/3 (324).tif[0].txt
#   inflating: out_pages/single/3 (325).tif[0].docx
#   inflating: out_pages/single/3 (325).tif[0].txt
#   inflating: out_pages/single/3 (326).tif[0].docx
#   inflating: out_pages/single/3 (326).tif[0].txt
#   inflating: out_pages/single/3 (327).tif[0].docx
#   inflating: out_pages/single/3 (327).tif[0].txt
#   inflating: out_pages/single/3 (328).tif[0].docx
#   inflating: out_pages/single/3 (328).tif[0].txt
#   inflating: out_pages/single/3 (329).tif[0].docx
#   inflating: out_pages/single/3 (329).tif[0].txt
#   inflating: out_pages/single/3 (33).tif[0].docx
#   inflating: out_pages/single/3 (33).tif[0].txt
#   inflating: out_pages/single/3 (330).tif[0].docx
#   inflating: out_pages/single/3 (330).tif[0].txt
#   inflating: out_pages/single/3 (331).tif[0].docx
#   inflating: out_pages/single/3 (331).tif[0].txt
#   inflating: out_pages/single/3 (332).tif[0].docx
#   inflating: out_pages/single/3 (332).tif[0].txt
#   inflating: out_pages/single/3 (333).tif[0].docx
#   inflating: out_pages/single/3 (333).tif[0].txt
#   inflating: out_pages/single/3 (334).tif[0].docx
#   inflating: out_pages/single/3 (334).tif[0].txt
#   inflating: out_pages/single/3 (335).tif[0].docx
#   inflating: out_pages/single/3 (335).tif[0].txt
#   inflating: out_pages/single/3 (336).tif[0].docx
#   inflating: out_pages/single/3 (336).tif[0].txt
#   inflating: out_pages/single/3 (337).tif[0].docx
#   inflating: out_pages/single/3 (337).tif[0].txt
#   inflating: out_pages/single/3 (339).tif[0].docx
#   inflating: out_pages/single/3 (339).tif[0].txt
#   inflating: out_pages/single/3 (34).tif[0].docx
#   inflating: out_pages/single/3 (34).tif[0].txt
#   inflating: out_pages/single/3 (340).tif[0].docx
#   inflating: out_pages/single/3 (340).tif[0].txt
#   inflating: out_pages/single/3 (341).tif[0].docx
#   inflating: out_pages/single/3 (341).tif[0].txt
#   inflating: out_pages/single/3 (342).tif[0].docx
#   inflating: out_pages/single/3 (342).tif[0].txt
#   inflating: out_pages/single/3 (343).tif[0].docx
#   inflating: out_pages/single/3 (343).tif[0].txt
#   inflating: out_pages/single/3 (344).tif[0].docx
#   inflating: out_pages/single/3 (344).tif[0].txt
#   inflating: out_pages/single/3 (345).tif[0].docx
#   inflating: out_pages/single/3 (345).tif[0].txt
#   inflating: out_pages/single/3 (346).tif[0].docx
#   inflating: out_pages/single/3 (346).tif[0].txt
#   inflating: out_pages/single/3 (347).tif[0].docx
#   inflating: out_pages/single/3 (347).tif[0].txt
#   inflating: out_pages/single/3 (348).tif[0].docx
#   inflating: out_pages/single/3 (348).tif[0].txt
#   inflating: out_pages/single/3 (349).tif[0].docx
#   inflating: out_pages/single/3 (349).tif[0].txt
#   inflating: out_pages/single/3 (35).tif[0].docx
#   inflating: out_pages/single/3 (35).tif[0].txt
#   inflating: out_pages/single/3 (350).tif[0].docx
#   inflating: out_pages/single/3 (350).tif[0].txt
#   inflating: out_pages/single/3 (351).tif[0].docx
#   inflating: out_pages/single/3 (351).tif[0].txt
#   inflating: out_pages/single/3 (352).tif[0].docx
#   inflating: out_pages/single/3 (352).tif[0].txt
#   inflating: out_pages/single/3 (354).tif[0].docx
#   inflating: out_pages/single/3 (354).tif[0].txt
#   inflating: out_pages/single/3 (355).tif[0].docx
#   inflating: out_pages/single/3 (355).tif[0].txt
#   inflating: out_pages/single/3 (356).tif[0].docx
#   inflating: out_pages/single/3 (356).tif[0].txt
#   inflating: out_pages/single/3 (357).tif[0].docx
#   inflating: out_pages/single/3 (357).tif[0].txt
#   inflating: out_pages/single/3 (358).tif[0].docx
#   inflating: out_pages/single/3 (358).tif[0].txt
#   inflating: out_pages/single/3 (359).tif[0].docx
#   inflating: out_pages/single/3 (359).tif[0].txt
#   inflating: out_pages/single/3 (36).tif[0].docx
#   inflating: out_pages/single/3 (36).tif[0].txt
#   inflating: out_pages/single/3 (360).tif[0].docx
#   inflating: out_pages/single/3 (360).tif[0].txt
#   inflating: out_pages/single/3 (362).tif[0].docx
#   inflating: out_pages/single/3 (362).tif[0].txt
#   inflating: out_pages/single/3 (363).tif[0].docx
#   inflating: out_pages/single/3 (363).tif[0].txt
#   inflating: out_pages/single/3 (365).tif[0].docx
#   inflating: out_pages/single/3 (365).tif[0].txt
#   inflating: out_pages/single/3 (366).tif[0].docx
#   inflating: out_pages/single/3 (366).tif[0].txt
#   inflating: out_pages/single/3 (367).tif[0].docx
#   inflating: out_pages/single/3 (367).tif[0].txt
#   inflating: out_pages/single/3 (368).tif[0].docx
#   inflating: out_pages/single/3 (368).tif[0].txt
#   inflating: out_pages/single/3 (369).tif[0].docx
#   inflating: out_pages/single/3 (369).tif[0].txt
#   inflating: out_pages/single/3 (37).tif[0].docx
#   inflating: out_pages/single/3 (37).tif[0].txt
#   inflating: out_pages/single/3 (370).tif[0].docx
#   inflating: out_pages/single/3 (370).tif[0].txt
#   inflating: out_pages/single/3 (371).tif[0].docx
#   inflating: out_pages/single/3 (371).tif[0].txt
#   inflating: out_pages/single/3 (372).tif[0].docx
#   inflating: out_pages/single/3 (372).tif[0].txt
#   inflating: out_pages/single/3 (373).tif[0].docx
#   inflating: out_pages/single/3 (373).tif[0].txt
#   inflating: out_pages/single/3 (374).tif[0].docx
#   inflating: out_pages/single/3 (374).tif[0].txt
#   inflating: out_pages/single/3 (375).tif[0].docx
#   inflating: out_pages/single/3 (375).tif[0].txt
#   inflating: out_pages/single/3 (376).tif[0].docx
#   inflating: out_pages/single/3 (376).tif[0].txt
#   inflating: out_pages/single/3 (377).tif[0].docx
#   inflating: out_pages/single/3 (377).tif[0].txt
#   inflating: out_pages/single/3 (378).tif[0].docx
#   inflating: out_pages/single/3 (378).tif[0].txt
#   inflating: out_pages/single/3 (379).tif[0].docx
#   inflating: out_pages/single/3 (379).tif[0].txt
#   inflating: out_pages/single/3 (38).tif[0].docx
#   inflating: out_pages/single/3 (38).tif[0].txt
#   inflating: out_pages/single/3 (380).tif[0].docx
#   inflating: out_pages/single/3 (380).tif[0].txt
#   inflating: out_pages/single/3 (381).tif[0].docx
#   inflating: out_pages/single/3 (381).tif[0].txt
#   inflating: out_pages/single/3 (382).tif[0].docx
#   inflating: out_pages/single/3 (382).tif[0].txt
#   inflating: out_pages/single/3 (383).tif[0].docx
#   inflating: out_pages/single/3 (383).tif[0].txt
#   inflating: out_pages/single/3 (384).tif[0].docx
#   inflating: out_pages/single/3 (384).tif[0].txt
#   inflating: out_pages/single/3 (385).tif[0].docx
#   inflating: out_pages/single/3 (385).tif[0].txt
#   inflating: out_pages/single/3 (386).tif[0].docx
#   inflating: out_pages/single/3 (386).tif[0].txt
#   inflating: out_pages/single/3 (387).tif[0].docx
#   inflating: out_pages/single/3 (387).tif[0].txt
#   inflating: out_pages/single/3 (388).tif[0].docx
#   inflating: out_pages/single/3 (388).tif[0].txt
#   inflating: out_pages/single/3 (389).tif[0].docx
#   inflating: out_pages/single/3 (389).tif[0].txt
#   inflating: out_pages/single/3 (39).tif[0].docx
#   inflating: out_pages/single/3 (39).tif[0].txt
#   inflating: out_pages/single/3 (390).tif[0].docx
#   inflating: out_pages/single/3 (390).tif[0].txt
#   inflating: out_pages/single/3 (391).tif[0].docx
#   inflating: out_pages/single/3 (391).tif[0].txt
#   inflating: out_pages/single/3 (393).tif[0].docx
#   inflating: out_pages/single/3 (393).tif[0].txt
#   inflating: out_pages/single/3 (394).tif[0].docx
#   inflating: out_pages/single/3 (394).tif[0].txt
#   inflating: out_pages/single/3 (395).tif[0].docx
#   inflating: out_pages/single/3 (395).tif[0].txt
#   inflating: out_pages/single/3 (396).tif[0].docx
#   inflating: out_pages/single/3 (396).tif[0].txt
#   inflating: out_pages/single/3 (397).tif[0].docx
#   inflating: out_pages/single/3 (397).tif[0].txt
#   inflating: out_pages/single/3 (398).tif[0].docx
#   inflating: out_pages/single/3 (398).tif[0].txt
#   inflating: out_pages/single/3 (399).tif[0].docx
#   inflating: out_pages/single/3 (399).tif[0].txt
#   inflating: out_pages/single/3 (4).tif[0].docx
#   inflating: out_pages/single/3 (4).tif[0].txt
#   inflating: out_pages/single/3 (400).tif[0].docx
#   inflating: out_pages/single/3 (400).tif[0].txt
#   inflating: out_pages/single/3 (401).tif[0].docx
#   inflating: out_pages/single/3 (401).tif[0].txt
#   inflating: out_pages/single/3 (402).tif[0].docx
#   inflating: out_pages/single/3 (402).tif[0].txt
#   inflating: out_pages/single/3 (403).tif[0].docx
#   inflating: out_pages/single/3 (403).tif[0].txt
#   inflating: out_pages/single/3 (405).tif[0].docx
#   inflating: out_pages/single/3 (405).tif[0].txt
#   inflating: out_pages/single/3 (406).tif[0].docx
#   inflating: out_pages/single/3 (406).tif[0].txt
#   inflating: out_pages/single/3 (408).tif[0].docx
#   inflating: out_pages/single/3 (408).tif[0].txt
#   inflating: out_pages/single/3 (409).tif[0].docx
#   inflating: out_pages/single/3 (409).tif[0].txt
#   inflating: out_pages/single/3 (41).tif[0].docx
#   inflating: out_pages/single/3 (41).tif[0].txt
#   inflating: out_pages/single/3 (410).tif[0].docx
#   inflating: out_pages/single/3 (410).tif[0].txt
#   inflating: out_pages/single/3 (413).tif[0].docx
#   inflating: out_pages/single/3 (413).tif[0].txt
#   inflating: out_pages/single/3 (414).tif[0].docx
#   inflating: out_pages/single/3 (414).tif[0].txt
#   inflating: out_pages/single/3 (415).tif[0].docx
#   inflating: out_pages/single/3 (415).tif[0].txt
#   inflating: out_pages/single/3 (416).tif[0].docx
#   inflating: out_pages/single/3 (416).tif[0].txt
#   inflating: out_pages/single/3 (417).tif[0].docx
#   inflating: out_pages/single/3 (417).tif[0].txt
#   inflating: out_pages/single/3 (418).tif[0].docx
#   inflating: out_pages/single/3 (418).tif[0].txt
#   inflating: out_pages/single/3 (419).tif[0].docx
#   inflating: out_pages/single/3 (419).tif[0].txt
#   inflating: out_pages/single/3 (42).tif[0].docx
#   inflating: out_pages/single/3 (42).tif[0].txt
#   inflating: out_pages/single/3 (420).tif[0].docx
#   inflating: out_pages/single/3 (420).tif[0].txt
#   inflating: out_pages/single/3 (421).tif[0].docx
#   inflating: out_pages/single/3 (421).tif[0].txt
#   inflating: out_pages/single/3 (422).tif[0].docx
#   inflating: out_pages/single/3 (422).tif[0].txt
#   inflating: out_pages/single/3 (423).tif[0].docx
#   inflating: out_pages/single/3 (423).tif[0].txt
#   inflating: out_pages/single/3 (424).tif[0].docx
#   inflating: out_pages/single/3 (424).tif[0].txt
#   inflating: out_pages/single/3 (425).tif[0].docx
#   inflating: out_pages/single/3 (425).tif[0].txt
#   inflating: out_pages/single/3 (426).tif[0].docx
#   inflating: out_pages/single/3 (426).tif[0].txt
#   inflating: out_pages/single/3 (427).tif[0].docx
#   inflating: out_pages/single/3 (427).tif[0].txt
#   inflating: out_pages/single/3 (428).tif[0].docx
#   inflating: out_pages/single/3 (428).tif[0].txt
#   inflating: out_pages/single/3 (429).tif[0].docx
#   inflating: out_pages/single/3 (429).tif[0].txt
#   inflating: out_pages/single/3 (430).tif[0].docx
#   inflating: out_pages/single/3 (430).tif[0].txt
#   inflating: out_pages/single/3 (431).tif[0].docx
#   inflating: out_pages/single/3 (431).tif[0].txt
#   inflating: out_pages/single/3 (434).tif[0].docx
#   inflating: out_pages/single/3 (434).tif[0].txt
#   inflating: out_pages/single/3 (435).tif[0].docx
#   inflating: out_pages/single/3 (435).tif[0].txt
#   inflating: out_pages/single/3 (436).tif[0].docx
#   inflating: out_pages/single/3 (436).tif[0].txt
#   inflating: out_pages/single/3 (437).tif[0].docx
#   inflating: out_pages/single/3 (437).tif[0].txt
#   inflating: out_pages/single/3 (438).tif[0].docx
#   inflating: out_pages/single/3 (438).tif[0].txt
#   inflating: out_pages/single/3 (439).tif[0].docx
#   inflating: out_pages/single/3 (439).tif[0].txt
#   inflating: out_pages/single/3 (44).tif[0].docx
#   inflating: out_pages/single/3 (44).tif[0].txt
#   inflating: out_pages/single/3 (440).tif[0].docx
#   inflating: out_pages/single/3 (440).tif[0].txt
#   inflating: out_pages/single/3 (441).tif[0].docx
#   inflating: out_pages/single/3 (441).tif[0].txt
#   inflating: out_pages/single/3 (442).tif[0].docx

# %%
# !find SplitDocsRes/Invoice_tr -type f -name "*.txt" > txt_tr.txt

# %%
# !find SplitDocsRes/Invoice_test -type f -name "*.txt" > txt_test.txt

# %%
! ls SplitDocsRes/Invoice_tr/
# Out:
# first  intermediate  last  single

# %%
list_of_texts = []
list_of_clases = []
clases = ['first','intermediate',  'last',  'single']
with open("txt_test.txt") as file:
    for line in file:
        file_name = line.rstrip()
        file_ = open(file_name,"rb") 
        x = file_.read()
        list_of_texts.append(x.decode("utf-16"))
        list_of_clases.append(file_name)
        file_.close()

# %%
print(list_of_clases)
# Out:
# ['SplitDocsRes/Invoice_tr/single/~~$42.tmp_10729.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/goodman fielder_clean5.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/38 (2).tif[0].txt', 'SplitDocsRes/Invoice_tr/single/20190131150048_00001.jpg[0].txt', 'SplitDocsRes/Invoice_tr/single/daiichi houki 220.TIF[0].txt', 'SplitDocsRes/Invoice_tr/single/Tokyou nissan 255.TIF[0].txt', 'SplitDocsRes/Invoice_tr/single/CT.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/Testfacturen Abbyy (83).tif[0].txt', 'SplitDocsRes/Invoice_tr/single/0522.TIF[0].txt', 'SplitDocsRes/Invoice_tr/single/67b291eb-090a-4acc-94f7-72419c752807.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/0419.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Page1.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Page_5.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Austria_0509_I0702-g02jlj__00237D37568C1ED3948680F0DB494036.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/Image_00000012__e59c8aed-0268-42e1-aa8a-bc9bac0e99cf__.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/McLearie.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/Portugal_FT_259_2018.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/Page_1.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/00000947.TIF[0].txt', 'SplitDocsRes/Invoice_tr/single/CA-French_Image_00000004.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/000004A9.TIF[0].txt', 'SplitDocsRes/Invoice_tr/single/Portugal_Page5.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/10.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/016dc023-0161-4c0e-8524-aa2d63354e16.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Ireland_Image_00000005_5.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Winnebago Mfg Co__aa40d25a-6053-4b67-80ce-91e0fcf273ab__.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/Page_10.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Page_190.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Canon2F1572-QuickConnect-03172011-094323_5677.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/France_Lima_Page1.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/kuva_As Oy Otsontähti_140_41-262 (ID 7022229).pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/0047.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Page_218.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/000006D5.TIF[0].txt', 'SplitDocsRes/Invoice_tr/single/Estonia_EuroPark.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/~~$2B.tmp_10825.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/Page_32.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Canon2F1572-QuickConnect-03162011-115843_5114_clean.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/Image_00000053__dffcbc67-d486-4e52-b913-f6262fae1f50__.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/39.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/SAMPLE (265).TIF[0].txt', 'SplitDocsRes/Invoice_tr/single/star2_clean1.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/Page_491.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/101184_0000.TIF[0].txt', 'SplitDocsRes/Invoice_tr/single/Croatia_CZCC2824GIN130118960_GMSCZ_01227805.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/899ac036-c03e-4ea6-af86-3827b4b981eb.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/26 (4).tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Image_00000027_ (84)__f7901e82-4b33-4bfc-86a6-f2a786278f78__.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Anchor Fluid Power.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/9b6d3c33-12e8-4d0d-a855-2cd5a8990f3e.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/f10e7823-2c87-4ee4-80e9-5e24d9d6a9bc.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/29e3bb1e-a4a9-4cfa-9c2f-fdbe14593cad.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/~~$159.tmp_2687.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/EU-English_Rechnung38.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/Austria_47.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/aspire_clean3.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/Page_43.tif[0].txt', 'SplitDocsRes/Invoice_tr/single/fare game_clean2.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/Austria_0196_I0196-A96LAW__AC162D8A39D21EE396A15D66723BC841.pdf[0].txt', 'SplitDocsRes/Invoice_tr/single/Page_34.tif[0]. ...

# %%
classes = []
for cl in list_of_clases:
  spliting = cl.split(sep='/')[2]
  #print(spliting)
  classes.append(spliting)

# %%
import pandas as pd

data = {'Text':list_of_texts,
        'MLclass':classes}
train = pd.DataFrame(data)

# %%
train.head()
# Out:
#                                                 Text MLclass
# 0  Ryder\r\nEver better.\r\nInvoice\r\n6 April 20...  single
# 1  j 'ivauu ii\r\nA-5300 HALLWANu-SALZBURG WiQngr...  single
# 2  Anthony Ferguson\r\nINVOICE\r\nCrossways The C...  single
# 3  RICEVUTA FISCALE - FATTURA\r\n(Legge 30 dicemb...  single
# 4  FACTURE:FACT-016436\r\nCentre ^ France\r\nLAMO...  single

# %%
train.to_csv("test.csv")

# %%
! cp

# %% [markdown]
# # Новый раздел

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
from gensim.models import Doc2Vec
from sklearn import utils
from sklearn.model_selection import train_test_split
import gensim
from sklearn.linear_model import LogisticRegression
from gensim.models.doc2vec import TaggedDocument
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd


train = pd.read_csv('train_6128.csv')
test = pd.read_csv('test_1532.csv')

# %%
X_train.shape
# Out:
# (1007, 2)

# %%
y_test.shape
# Out:
# (497, 2)

# %%
import nltk
from nltk.corpus import stopwords
def tokenize_text(text):
    tokens = []
    for sent in nltk.sent_tokenize(text):
        for word in nltk.word_tokenize(sent):
            if len(word) < 2:
                continue
            tokens.append(word.lower())
    return tokens

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
train['MLclass'] = train['MLclass'].astype('str')
test['MLclass'] = test['MLclass'].astype('str')

# %%
train['Text'] = train['Text'].astype('str')
test['Text'] = test['Text'].astype('str')

# %%
cnt_pro = train['MLclass'].value_counts()
plt.figure(figsize=(12,4))
sns.barplot(cnt_pro.index, cnt_pro.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Product', fontsize=12)
plt.xticks(rotation=90)
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
cnt_pro = test['MLclass'].value_counts()
plt.figure(figsize=(12,4))
sns.barplot(cnt_pro.index, cnt_pro.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Product', fontsize=12)
plt.xticks(rotation=90)
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
train_tagged = train.apply(
    lambda r: TaggedDocument(words=tokenize_text(r['Text']), tags=[r.MLclass]), axis=1)
test_tagged = test.apply(
    lambda r: TaggedDocument(words=tokenize_text(r['Text']), tags=[r.MLclass]), axis=1)

# %%
train.dtypes
# Out:
# Unnamed: 0     int64
# Text          object
# MLclass       object
# dtype: object

# %%
import multiprocessing

from gensim.models import Doc2Vec

from tqdm import tqdm
cores = multiprocessing.cpu_count()
model_dbow = Doc2Vec(dm=0, vector_size=300, negative=5, hs=0, min_count=2, sample = 0, workers=cores)
model_dbow.build_vocab([x for x in tqdm(train_tagged.values)])
# Out:
# 100%|██████████| 6128/6128 [00:00<00:00, 561721.59it/s]

# %%
# %%time
for epoch in range(30):
    model_dbow.train(utils.shuffle([x for x in tqdm(train_tagged.values)]), total_examples=len(train_tagged.values), epochs=1)
    model_dbow.alpha -= 0.002
    model_dbow.min_alpha = model_dbow.alpha
# Out:
# 100%|██████████| 6128/6128 [00:00<00:00, 1203140.71it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1135930.30it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1033357.25it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1154295.37it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1161703.72it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1190159.98it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1119796.75it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1197758.28it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1180755.92it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1182331.06it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1210963.25it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 2397192.21it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 2371534.87it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 2365859.25it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 2410456.24it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 2151033.13it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 2247524.91it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 2278809.73it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1677502.60it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1248794.82it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1206302.85it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 2303521.68it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 2492020.06it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 2332156.33it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1110795.41it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 546656.49it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 562532.99it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 740370.29it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 728782.32it/s]
# 100%|██████████| 6128/6128 [00:00<00:00, 1068363.74it/s]
# CPU times: user 2min 8s, sys: 1.38 s, total: 2min 9s
# Wall time: 1min 19s

# %%
def vec_for_learning(model, tagged_docs):
    sents = tagged_docs.values
    targets, regressors = zip(*[(doc.tags[0], model.infer_vector(doc.words, steps=20)) for doc in sents])
    return targets, regressors

# %%
y_train, X_train = vec_for_learning(model_dbow, train_tagged)
y_test, X_test = vec_for_learning(model_dbow, test_tagged)

# %%
logreg = LogisticRegression(n_jobs=1, C=1e5, class_weight="balanced")
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
from sklearn.metrics import accuracy_score, f1_score

print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Testing accuracy 0.3674934725848564
# Testing F1 score: 0.4476948207744089

# %%
from sklearn.metrics import  plot_confusion_matrix
plot_confusion_matrix(logreg, y_test, y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-023d1dc56f3a> in <module>()
#       1 from sklearn.metrics import  plot_confusion_matrix
# ----> 2 plot_confusion_matrix(logreg, y_test, y_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py in wrapped(*args, **kwargs)
#      86         def wrapped(*args, **kwargs):
#      87             warnings.warn(msg, category=FutureWarning)
# ---> 88             return fun(*args, **kwargs)
#      89
#      90         wrapped.__doc__ = self._update_doc(wrapped.__doc__)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_plot/confusion_matrix.py in plot_confusion_matrix(estimator, X, y_true, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax, colorbar)
#     563         raise ValueError("plot_confusion_matrix only supports classifiers")
#     564
# --> 565     y_pred = estimator.predict(X)
#     566     cm = confusion_matrix(
#     567         y_true, y_pred, sample_weight=sample_weight, labels=labels, normalize=normalize
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     405         check_is_fitted(self)
#     406
# --> 407         X = self._validate_data(X, accept_sparse="csr", reset=False)
#     408         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     409         return scores.ravel() if scores.shape[1] == 1 else scores
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     771                     "Reshape your data either using array.reshape(-1, 1) if "
#     772                     "your data has a single feature or array.reshape(1, -1) "
# --> 773                     "if it contains a single sample.".format(array)
#     774                 )
#     775
#
# ValueError: Expected 2D array, got 1D array instead:
# array=['single' 'single' 'single' ... 'single' 'single' 'single'].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
